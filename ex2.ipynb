# %%
jin = person() # jin은 person의 인스턴스
jin.hello()

1 = a = int(10)
2 print(a)

b = list(range(10))
print(b)

a = 10
print(type(a))

b = [1, 2, 3]

# %%
1 # 빈 클래스 만들기
2 class person:
3   def hello(seif):
        print('hello')

# %%
class person():
    def__inir__(self):
        self.hello = "안녕하세요" 
    
    def hi(self):
       print(self.hello)

)
# Out:
#   Cell In[1], line 8
#     )
#     ^
# SyntaxError: unmatched ')'

# %%
class person():
   def__init__(slef, name, age, hobby):
     selp.name = '안녕하세요'
     selp.age = age
     selp. hobb =  hobb
    
    def intro

# %%
class person:
     pass
jin = person()
print = '진'

# %%
class person():
   def__init__(slef, name, age, hobb, weight):
     self.name = '안녕하세요'
     self.age = age
     self. hoby =  hobby
     self.__weight = weigh
   jin = (', ')

# %%
class person():
    def__Hello(self):
    print('hello')
