# %%
print("하이")
print("하이")
print("하이")

# %%
print("dPwp1")
s = "안녕하세요."

print("== 길이 출력 ==")
print(len(s))

#s[start:end(-1):step]
print("s를 이루는 문자 중에서 앞에 거 2개 출력")
print(s[0:2])

print("a를 이루는 문장 중에서 문자 하나 건너 뛰고  1개 출력")
print(s[1:2])

print(s[:4])
print(s[:4])

print("a를 이루는 문장 중에서 문자 3개 건너 뛰고  전부 출력")
print(s[3:len(s)])

print("s를 이루는 문장 중에서 앞에 문자 3개 건너 뛰고 나머지  전부 출력" 뒤 인덱스생략")
print(s[3:])

print("s를 이루는 문자를 하나씩 출력, for")
for c in :
    print(c)

# %%
s ="a안b녕c하d세e요f"

print("s를 이루는 문장 중에서 한글만 출력, for, if, or continue, 방법 1")
for c in s:
    if c == 'a' or c == 'c' or 'c'== 'd' 'e' or 'c'

print("s를 이루는 문장 중에서 한글만 출력, for, if, or continue, 방법 2")
