# %%
import expy

expy.fun1()
# Out:
# '모듈에 있는 첫 번째 함수'

# %%
form ex1 import fun1, fun2

#fun1()
#fun2()
# 이런식으로만 호출하면 마지막 것만 출력
# 안되는 경우 다시 vscode를 껐다 키면 됨

print(fun1())
print(fun2())
# Out:
#   Cell In[20], line 1
#     form ex1 import fun1, fun2
#          ^
# SyntaxError: invalid syntax

# %%
라러리
-여러개의 모듈들을 묶어서 특정 기능을 제공하는 패키지 집합
여러모듈+하위 패키지구조
ㅍ준 라이브러리

#날짜/ 시간 라이브러리
#날짜와 ㅅ시간을 다루는 모듈
#현재 시간 확인, 날짜 계산 사용
import datetime

현대시간 출력

# %%
# 난수 라이브리

#난수모듈
# 무작위 값을 생성하는 모듈
# 게임, 추첨, 테스트 데이터에 사용

import random

# 1qnxj 100Rkwl

import math

# 시간 제어 모듈
# 시간 흐름을 제어하는 모듈
# 시간을 잠시 멈출때 사용

# %%
# 시스템오류
# 파이썬 실행 환경을 다루는 모듈
# 버전 확인, 프로그램 종료 사용

import sys

현재 사영중인 파이썸 버전 출력
print(sys.version)

# %%
#운영체제 모듈
# 운영체제(os)와 관련된 기능

import os

# %%
# 데이터 형식모듈
# -JSON :데이터를 약속된 모양으로 적는 방식 ("key" : "Value")
# 웹 API, 파일 저장에 사용
# = API : 프로그램

# %%
# 정규 표현식모듈
# 문자열 패턴 검사 모듈
# 형식 확인(아이디, 이메일 등)에 사용


import re

# 문자열이 "hi"로 시작하는지 확인
print(bool)

# %%
# csv 파일 모듈
# csv(엑셀) 팡리을 읽고 쓰는 모듈
# 데이타 저장/븐석 기초에 사용
import csv

with open("test,csv", "w")

# %%
# 자료구조 모듈
# 자료구조를 편하게 쓰도록 도와줌 #카운트, 큐, 딕셔너리 확장기능 제공

from collections

# %%
# 수학 모듈
# 수학 계산 기능을 제공하는 모듈
# 제곱근, 삼각함수, 원주율 등을 포함

import math

# 16의 제곱근 계산
print(math.sqrt(16))
4.0
# 난수 모듈
# 무작위 값을 생성하는 모듈
# 게임, 추첨, 테스트 데이터에 사용

import random

# 1부터 100까지 중 랜덤한 숫자 1개 출력
print(random.randint(1, 100))
63
# 날짜/시간 모듈
# 날짜와 시간을 다루는 모듈
# 현재 시간 확인, 날짜 계산 사용
import datetime

# 현재 날짜와 시간을 출력
print(datetime.datetime.now())
2026-02-26 13:09:13.702187
# 시간 제어 모듈
# 시간 흐름을 제어하는 모듈
# 프로그램을 잠시 멈출 때 사용

import time

# 프로그램을 3초 동안 멈춤
time.sleep(3)

# 3초가 지난 후 출력
print("3초 후 실행")
3초 후 실행
# 시스템 모듈
# 파이썬 실행 환경을 다루는 모듈
# 버전 확인, 프로그램 종료 사용

import sys

# 현재 사용중인 파이썬 버전 출력
print(sys.version)
3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]
# 운영체제 모듈
# 운영체제(OS)와 관련된 기능 제공
# 파일/폴더 경로 처리에 사용

import os

# 현재 작업중인 폴더 경로 출력
print(os.getcwd())
c:\work\exam
# 데이터 형식 모듈
# JSON 형식으로 데이터를 변환
# - JSON : 데이터를 약속된 모양으로 적는 방식("key" : "value")
# 웹, API, 파일 저장에 사용
# - API : 프로그램끼리 대화하는 방법(규칙)

import json

data = {"name" : "jin", "age" : 20}
print(json.dumps(data))
{"name": "jin", "age": 20}
# 정규표현식 모듈
# 문자열 패턴 검사 모듈
# 형식 확인(아이디, 이메일 등)에 사용

import re

# 문자열이 "hi"로 시작하는지 확인
print(bool(re.match('hi', 'hi python')))
True
# CSV 파일 모듈
# CSV(엑셀) 파일을 읽고 쓰는 모듈
# 데이터 저장/분석 기초에 사용

import csv

# CSV 파일에 한 줄 데이터를 저장
with open('test.csv', 'w', newline='') as f:
    csv.writer(f).writerow(['name', 'score'])
# 자료구조 모듈
# 자료구조를 편하게 쓰도록 도와줌
# 카운트, 큐, 딕셔너리 확장 기능 제공

from collections import Counter

# 문자열에서 각 글자의 개수를 셈
print(Counter("apple"))

# %%
외부 라이브러리
# Out:
#   Cell In[21], line 1
#     외부 라이브러리
#        ^
# SyntaxError: invalid syntax
