# %%
#어노테이션
age: int = 30
age: int = "안녕"
print(age)


# a는 int
# b는 int
def add(a:int, b:int) = IndentationError

numbers: list[int] = [1, 2, 3]
person: dict[str, int] ={
    "age" : 30,
    "height: 170"
}
print()
